# %%
import pandas as pd
import sqlite3

# %%
df=pd.read_csv('newLaptopInfo.csv',error_bad_lines = False )
# Out:
# C:\Users\KRISHNA PANDEY\AppData\Local\Temp\ipykernel_816\1048305282.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv('newLaptopInfo.csv',error_bad_lines = False )
# b'Skipping line 265: expected 9 fields, saw 11\nSkipping line 301: expected 9 fields, saw 11\nSkipping line 304: expected 9 fields, saw 11\nSkipping line 316: expected 9 fields, saw 11\nSkipping line 474: expected 9 fields, saw 18\nSkipping line 526: expected 9 fields, saw 16\nSkipping line 687: expected 9 fields, saw 13\nSkipping line 761: expected 9 fields, saw 10\nSkipping line 777: expected 9 fields, saw 10\nSkipping line 778: expected 9 fields, saw 18\nSkipping line 793: expected 9 fields, saw 10\nSkipping line 795: expected 9 fields, saw 13\nSkipping line 798: expected 9 fields, saw 10\nSkipping line 826: expected 9 fields, saw 12\n'

# %%
df
# Out:
#                                            ProductName  stars  Ratings  \
# 0                        HP 15s Intel Core i3 11th Gen    4.3      762
# 1                        HP 14s Intel Core i3 11th Gen    4.3     4650
# 2                        HP 15s Intel Core i3 12th Gen    4.2      611
# 3                           HP Ryzen 5 Hexa Core 5500U    4.3     1823
# 4                           HP Ryzen 5 Hexa Core 5500U    4.2     2415
# ..                                                 ...    ...      ...
# 821                     DELL Inspiron Core i5 11th Gen    3.9       67
# 822                DELL Vostro Ryzen 7 Octa Core 5825U    5.0        3
# 823  ASUS ROG Strix G17 with 90Whr Battery Ryzen 9 ...    0.0        0
# 824               GIGABYTE AERO 5 KE4 Core i7 12th Gen    0.0        0
# 825      ASUS ROG Zephyrus M16 (2022) Core i9 12th Gen    4.7        3
#
#      CurrentPrice     MRP                           Processor             RAM  \
# ...

# %%
cnn=sqlite3.connect('jupyter_sql_tutorial.db')

# %%
df.to_sql('flipkart_table',cnn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.to_sql('flipkart_table',cnn)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite:///jupyter_sql_tutorial.db

# %%
# %%sql
# select*
# from flipkart_table
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(0, 'HP 15s Intel Core i3 11th Gen', 4.3, 762, 38990, 50585, 'Intel Core i3 Processor (11th Gen)', '8 GB DDR4 RAM', '512 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/xif0q/computer/j/r/j/-original-imagp7pfqggfaqqm.jpeg?q=70 '),
#  (1, 'HP 14s Intel Core i3 11th Gen', 4.3, 4650, 38490, 49509, 'Intel Core i3 Processor (11th Gen)', '8 GB DDR4 RAM', '512 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/xif0q/computer/f/g/c/-original-imagp7pfkztgtg93.jpeg?q=70 '),
#  (2, 'HP 15s Intel Core i3 12th Gen', 4.2, 611, 41990, 56261, 'Intel Core i3 Processor (12th Gen)', '8 GB DDR4 RAM', '512 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/xif0q/computer/o/l/e/-original-imagphhhan259czj.jpeg?q=70 '),
# ...

# %% [markdown]
# # Find the best rated Laptops

# %%
# %%sql
# SELECT *
# FROM flipkart_table
# WHERE stars >= 4.5 AND Ratings >= 1500
# ORDER BY stars DESC;
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(75, 'APPLE 2020 Macbook Air M1', 4.7, 10033, 77990, 99900, 'Apple M1 Processor', '8 GB DDR4 RAM', '256 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/kp5sya80/screen-guard/tempered-glass/o/v/n/apple-macbook-air-m1-13-3-inch-lightwings-original-imag3gh5xftgbpg3.jpeg?q=70 '),
#  (84, 'APPLE 2020 Macbook Air M1', 4.7, 10033, 77990, 99900, 'Apple M1 Processor', '8 GB DDR4 RAM', '256 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/khdqnbk0/computer/f/y/t/apple-original-imafxfyqydgvrkzv.jpeg?q=70 '),
#  (155, 'APPLE 2020 Macbook Air M1', 4.7, 10033, 81990, 99900, 'Apple M1 Processor', '8 GB DDR4 RAM', '256 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/kruyw7k0/computer/v/x/v/na-thin-and-light-laptop-apple-original-imag5jt7u9fzenqb.jpeg?q=70 '),
# ...

# %% [markdown]
# # So which Laptop was the best seller?

# %%
# %%sql
# SELECT *
# FROM flipkart_table
# ORDER BY Ratings DESC
# LIMIT 1;
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [(377, 'HP Pavilion Ryzen 5 Hexa Core AMD R5', 4.4, 12900, 68500, 69999, 'AMD Ryzen 5 Hexa Core Processor', '8 GB DDR4 RAM', '512 GB SSD', 'https://rukminim1.flixcart.com/image/312/312/kbqu4cw0/computer/q/x/r/hp-original-imaftyzachgrav8f.jpeg?q=70 ')]

# %% [markdown]
# # Having highest discount

# %%
# %%sql
# SELECT DISTINCT ProductName
# FROM flipkart_table
# where MRP-CurrentPrice>30000
# Out:
#  * sqlite:///jupyter_sql_tutorial.db
# Done.
# [('MSI Alpha 15 AMD Advantage Edition Ryzen 7 Octa Core 5800H',),
#  ('MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen',),
#  ('MSI Raider GE66 Core i7 12th Gen',),
#  ('MSI Core i7 13th Gen',),
#  ('MSI Core i5 12th Gen',),
#  ('MSI Stealth GS66 Core i7 12th Gen',),
#  ('MSI Core i9 13th Gen',),
#  ('MSI CreatorPro M16 Core i7 12th Gen',),
#  ('HP Core i7 12th Gen',),
#  ('HP Omen Intel Core i9 12th Gen',),
#  ('MSI Prestige 14 Core i7 10th Gen',),
#  ('HP Victus Ryzen 7 Octa Core 5800H',),
#  ('HP Intel Core i5 10th Gen',),
#  ('MSI Core i9 12th Gen',),
#  ('MSI Creator Z16 Core i9 11th Gen',),
#  ('MSI GS66 Core i7 11th Gen',),
#  ('HP HP Envy Ryzen 7 Octa Core 4700U',),
#  ('HP Spectre Intel Core i5 11th Gen',),
#  ('MSI Creator M16 Core i7 12th Gen',),
#  ('LG Gram 15 Core i5 10th Gen',),
#  ('MSI GT77 Titan Core i9 12th Gen',),
#  ('HP Envy Core i7 11th Gen',),
#  ('HP 15s Intel Core i9 11th Gen',),
# ...
